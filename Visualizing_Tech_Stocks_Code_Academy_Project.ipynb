# %%
import pandas as pd
import numpy as np

# %%
pip install pandas-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 50 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 50.4 MB/s
# ...
#      |████████████████████████████████| 128 kB 58.6 MB/s
# ...
#      |████████████████████████████████| 112 kB 64.7 MB/s
# ...
#      |████████████████████████████████| 110 kB 68.3 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
import pandas_datareader as web
import yfinance as yf

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from pandas.core.internals.blocks import ensure_wrapped_if_datetimelike
#Load the adjusted closing for the top 5 tech stocks 
symbols = ["MSFT", "AMZN", "AAPL", "GOOG", "META"]
start_date = "2019-01-01"
end_date = "2019-07-01"
stock_data = yf.download(symbols, start= start_date, end= end_date)
stock_data
# Out:
# [*********************100%***********************]  5 of 5 completed
#             Adj Close                                                \
#                  AAPL       AMZN       GOOG        META        MSFT
# Date
# 2019-01-02  38.105137  76.956497  52.292500  135.679993   96.874702
# 2019-01-03  34.309589  75.014000  50.803001  131.740005   93.310867
# 2019-01-04  35.774227  78.769501  53.535500  137.949997   97.650681
# 2019-01-07  35.694611  81.475502  53.419498  138.050003   97.775230
# 2019-01-08  36.375069  82.829002  53.813999  142.529999   98.484169
# ...               ...        ...        ...         ...         ...
# 2019-06-24  48.306976  95.695000  55.776001  192.600006  133.050018
# 2019-06-25  47.574749  93.913498  54.317501  188.839996  128.849335
# 2019-06-26  48.603748  94.891502  53.990002  187.660004  129.332214
# 2019-06-27  48.589146  95.213997  53.800499  189.500000  129.544617
# 2019-06-28  48.146416  94.681503  54.045502  193.000000  129.361145
#
# ...

# %%
stock_data['Adj Close']
# Out:
#                  AAPL       AMZN       GOOG        META        MSFT
# Date
# 2019-01-02  38.105137  76.956497  52.292500  135.679993   96.874702
# 2019-01-03  34.309589  75.014000  50.803001  131.740005   93.310867
# 2019-01-04  35.774227  78.769501  53.535500  137.949997   97.650681
# 2019-01-07  35.694611  81.475502  53.419498  138.050003   97.775230
# 2019-01-08  36.375069  82.829002  53.813999  142.529999   98.484169
# ...               ...        ...        ...         ...         ...
# 2019-06-24  48.306976  95.695000  55.776001  192.600006  133.050018
# 2019-06-25  47.574749  93.913498  54.317501  188.839996  128.849335
# 2019-06-26  48.603748  94.891502  53.990002  187.660004  129.332214
# 2019-06-27  48.589146  95.213997  53.800499  189.500000  129.544617
# 2019-06-28  48.146416  94.681503  54.045502  193.000000  129.361145
#
# [124 rows x 5 columns]

# %%
stock_data_closing_prices = stock_data['Adj Close']
stock_data_closing_prices.plot()
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price")
plt.title("Tech Stocks Adjusted Price Over Time")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Calculate and plot daily simple rate of return over time. 
stock_data_daily_ror = stock_data['Adj Close'].pct_change()
stock_data_daily_ror.plot()
plt.xlabel("Date")
plt.ylabel("ROR")
plt.title("Daily Simple Rate of Return Over time")
plt.figure(figsize =(16,9))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax1.plot(stock_data['Adj Close']['AMZN'].pct_change())
ax1.set_title("Amazon")
ax2.plot(stock_data['Adj Close']['AAPL'].pct_change())
ax2.set_title("Apple")
ax3.plot(stock_data['Adj Close']['META'].pct_change())
ax3.set_title("Facebook")
ax4.plot(stock_data['Adj Close']['MSFT'].pct_change())
ax4.set_title("Microsoft")
ax5.plot(stock_data['Adj Close']['GOOG'].pct_change())
ax5.set_title("Google")
plt.tight_layout()

# %%
#Calculate and plot the mean of each tech stock's daily simple rate of return 
daily_mean = stock_data_daily_ror.mean()
daily_mean
# Out:
# AAPL    0.002077
# AMZN    0.001826
# GOOG    0.000398
# META    0.003071
# MSFT    0.002449
# dtype: float64

# %%
daily_mean.keys()
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'META', 'MSFT'], dtype='object')

# %%
height = []
for key in daily_mean.keys():
  height.append(daily_mean[key])
height
# Out:
# [0.0020768392832676793,
#  0.0018261390390949346,
#  0.00039762592483612134,
#  0.003070590430211639,
#  0.0024485646618525405]

# %%
x_pos = np.arange(len(daily_mean.keys()))
x_pos
# Out:
# array([0, 1, 2, 3, 4])

# %%
# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_mean.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("daily mean")
plt.title("daily mean rate of return")

# show graphic
plt.show()

# %%
#Plot Variance 
daily_var =stock_data_daily_ror.var()
daily_var
# Out:
# AAPL    0.000346
# AMZN    0.000281
# GOOG    0.000258
# META    0.000412
# MSFT    0.000191
# dtype: float64

# %%
daily_var.keys()
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'META', 'MSFT'], dtype='object')

# %%
height = []
for key in daily_var.keys():
  height.append(daily_var[key])
height
# Out:
# [0.00034573566398490385,
#  0.0002811507048603559,
#  0.0002583750846989358,
#  0.00041169380009961517,
#  0.00019119146481674028]

# %%
#arrange keys on x axis based on length
x_pos = np.arange(len(daily_var.keys()))
x_pos
# Out:
# array([0, 1, 2, 3, 4])

# %%
# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_var.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("variance")
plt.title("daily variance")

# show graphic
plt.show()

# %%
#Calculate and plot Standard Deviation
daily_std = stock_data_daily_ror.std()

# %%
daily_std.keys()
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'META', 'MSFT'], dtype='object')

# %%
x_pos = np.arange(len(daily_std.keys()))

# %%
# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_std.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("std")
plt.title("daily std")

# show graphic
plt.show()

# %%
#Calculate the Correlations
stock_data_daily_ror.corr()
# Out:
#           AAPL      AMZN      GOOG      META      MSFT
# AAPL  1.000000  0.607934  0.566862  0.441240  0.651128
# AMZN  0.607934  1.000000  0.719873  0.574551  0.730200
# GOOG  0.566862  0.719873  1.000000  0.637025  0.634975
# META  0.441240  0.574551  0.637025  1.000000  0.456103
# MSFT  0.651128  0.730200  0.634975  0.456103  1.000000
